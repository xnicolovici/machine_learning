# %%
import pandas as pd

# %%
df = pd.read_csv('songs.csv')
df.head()
# Out:
#        Musician      Genre                Name  Decade Minutes
# 0  Led Zeppelin  hard rock  Stairway to Heaven      70   08:02
# 1  Led Zeppelin  hard rock             Kashmir      70   08:37
# 2  Led Zeppelin  hard rock      Immigrant Song      70   02:26
# 3  Led Zeppelin  hard rock    Whole Lotta Love      60   05:33
# 4  Led Zeppelin  hard rock           Black Dog      70   04:55

# %%
pivot_index=['Decade','Musician','Name']

def check_exist(x):
    return x
    

df.pivot_table(index=pivot_index, columns='Genre',values='Minutes',aggfunc=check_exist,fill_value='')
# Out:
# Genre                                          folk rock  hard rock pop rock
# Decade Musician     Name
# 60     Bob Dylan    Blowin' in the Wind             02:48
#                     Like a Rolling Stone            06:13
#        David Bowie  Space Oddity                                       05:15
#        Led Zeppelin Good Times Bad Times                      02:43
#                     I Can't Quit You Baby                     04:42
#                     Moby Dick                                 04:25
#                     Ramble On                                 04:35
#                     Whole Lotta Love                          05:33
# 70     Bob Dylan    Tangled Up in Blue              05:42
#        David Bowie  China Girl                                         05:08
#                     Golden Years                                       04:00
#                     Rebel Rebel                                        04:22
# ...
