# %% [markdown]
# Visualize MNIST with PCA
# ---

# %% [markdown]
# Exercise - Load data
# ---
#
# > **Exercise**: Load the ten thousand images and their labels from `mnist-10k.npz`.

# %%
import numpy as np

# import npz file
data=np.load('mnist-10k.npz')


# get data and labels
X=data['data']
y=data['labels']

print('X:', X.shape, X.dtype)
print('y:', y.shape, y.dtype)
# Out:
# X: (10000, 784) uint8
# y: (10000,) int32

# %% [markdown]
# Exercise - Visualize digits on a 2d plot
# ---
#
# > **Exercise**: Compute the first two principal components using all the images and then plot a subset of the database using them, e.g., 500 images.

# %%
# Create PCA transformer
pca = PCA(n_components=2)

# Apply PCA to rescaled data
X_2d = pca.fit_transform(X)

# %%
import matplotlib.pyplot as plt
# Plot proline and magnesium variables
plt.scatter(
    X_2d[:, 0], # Proline attribute
    X_2d[:, 1], # Magnesium attribute
    s=4
)
plt.xlabel('1st component')
plt.ylabel('2nd component')
plt.show()
