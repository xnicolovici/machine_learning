# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
train_df = pd.read_csv(os.path.join('data','house-prices.csv'))
train_df.shape

test_df = pd.read_csv(os.path.join('data','house-prices-test.csv'))
test_df.shape
# Out:
# (500, 81)

# %%
test_df['SalePrice'] = np.nan

# %%
test_df.shape
# Out:
# (500, 82)

# %%
data_df = pd.concat([train_df, test_df], ignore_index=True, sort=False)

# %%
data_df[data_df['SalePrice'].isnull()].shape
# Out:
# (500, 82)

# %%
data_df.shape
# Out:
# (2930, 82)

# %%
# Continuous variables
continuous_column = [
    '1st Flr SF', '2nd Flr SF', 'Lot Frontage', 'Lot Area', 'Mas Vnr Area', 'Bsmt Unf SF', 'BsmtFin SF 1', 'BsmtFin SF 2', 'Total Bsmt SF', 'Lot Frontage',
    'Low Qual Fin SF', 'Gr Liv Area', 'Garage Area', '3Ssn Porch', 'Open Porch SF', 'Wood Deck SF', 'Pool Area', 'Screen Porch', 'Misc Val', 'Enclosed Porch'
]

for c in continuous_column:
    temp_df = data_df[data_df[c] > 0]
    y=temp_df['SalePrice']
    plt.scatter(temp_df[c], y)
    plt.title(c)
    plt.show()
    #if c != '2nd Flr SF':
        #plt.hist(data_df[c],bins=30)
        #plt.title(c)
        #plt.show()

# %%
np.log1p(data_df[['Enclosed Porch']]).plot.hist()

# %%
column='Misc Val'
temp_df = data_df[np.abs(((data_df[column]-np.mean(data_df[column]))/np.std(data_df[column]))) < 3]
temp_df = data_df[data_df[column] > 0]
plt.scatter(temp_df[column], temp_df['SalePrice'])

# %%
column='Gr Liv Area'
temp_df = data_df[np.abs(((data_df[column]-np.mean(data_df[column]))/np.std(data_df[column]))) < 3]
temp_df = temp_df[temp_df[column] > 0]
plt.scatter(temp_df[column], temp_df['SalePrice'])

# %%
temp_df = zScoreCleanUp(train_df, continuous_column, factor=2)
# Out:
# /home/xavier/anaconda3/envs/exts-ml/lib/python3.6/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in less
#   from ipykernel import kernelapp as app

# %%
column='SalePrice'
data_df[np.abs(((data_df[column]-np.mean(data_df[column]))/np.std(data_df[column]))) < 3]['SalePrice'].plot.hist(bins=30)

# %%
temp_df = train_df.copy()
temp_df.shape
# Out:
# (2430, 82)

# %%
# Out:
# (0, 82)

# %%
zscore_values = zscore(data_df[continuous_column])

# %%
zscore_bool = np.abs(zscore_values) < 2
# Out:
# /home/xavier/anaconda3/envs/exts-ml/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in less
#   """Entry point for launching an IPython kernel.
